# %% [markdown]
# #### About the Data

# %% [markdown]
# <b>Ticket :</b> Ticket number assigned to each complaint<br>
# <b>Customer Complaint:</b>  Description of complaint<br>
# <b>Date:</b>  Date of complaint<br>
# <b>Time:</b> Time of complaint<br>
# <b>Received Via:</b>  Mode of communication of the complaint<br>
# <b>City:</b> Customer city<br>
# <b>State:</b> Customer state<br>
# <b>Zipcode:</b> Customer zip<br>
# <b>Status:</b> Status of complaint<br>

# %% [markdown]
# #### Problem Statements
# > * Provide the trend chart for the number of complaints at monthly and daily granularity levels
#
# > * Provide a table with the frequency of complaint types.
# > * Create a new categorical variable with value as Open and Closed.Open & Pending is to be categorized as Open and Closed & Solved is to be categorized as Closed.
# > * Provide state wise status of complaints in a stacked bar chart. Use the categorized variable from Q3. Provide insights on:
# >   * Which state has the maximum complaints
# >    * Which state has the highest percentage of unresolved complaints
# >        * Provide the percentage of complaints resolved till date, which were received through the Internet and customer care calls.
# ```

# %% [markdown]
# #### Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
date_fields = [['Date', 'Time']]

# %% [markdown]
# #### Importing data from the Local Library

# %%
df=pd.read_csv('E:\Study Materials\Python\Project\Comcast_telecom_complaints_data\Comcast.csv',parse_dates=date_fields,dayfirst=True)

# %%
df.head()
# Out:
#             Date_Time Ticket #  \
# 0 2015-04-22 15:53:50   250635
# 1 2015-08-04 10:22:56   223441
# 2 2015-04-18 09:55:47   242732
# 3 2015-07-05 11:59:35   277946
# 4 2015-05-26 13:25:26   307175
#
#                                   Customer Complaint Date_month_year  \
# 0                      Comcast Cable Internet Speeds       22-Apr-15
# 1       Payment disappear - service got disconnected       04-Aug-15
# 2                                  Speed and Service       18-Apr-15
# 3  Comcast Imposed a New Usage Cap of 300GB that ...       05-Jul-15
# 4         Comcast not working and no service to boot       26-May-15
#
#          Received Via      City     State  Zip code  Status  \
# 0  Customer Care Call  Abingdon  Maryland     21009  Closed
# 1            Internet   Acworth   Georgia     30102  Closed
# 2            Internet   Acworth   Georgia     30101  Closed
# 3            Internet   Acworth   Georgia     30101    Open
# 4            Internet   Acworth   Georgia     30101  Solved
#
#   Filing on Behalf of Someone
# 0                          No
# 1                          No
# 2                         Yes
# 3                         Yes
# 4                          No

# %%
df.sample(5)
# Out:
#                Date_Time Ticket #  \
# 2159 2015-06-24 12:21:14   361630
# 1392 2015-06-22 11:41:30   355447
# 612  2015-04-24 19:20:07   256312
# 925  2015-05-19 10:14:11   296536
# 333  2015-05-20 17:47:50   300124
#
#                                      Customer Complaint Date_month_year  \
# 2159                                     Egregious Fees       24-Jun-15
# 1392  Comcast- not responsive to multiple requests f...       22-Jun-15
# 612                  Comcast poor service or throttling       24-Apr-15
# 925                                     Comcast billing       19-May-15
# 333                                    Comcast internet       20-May-15
#
#             Received Via          City         State  Zip code  Status  \
# 2159  Customer Care Call   West Monroe     Louisiana     71291  Solved
# 1392  Customer Care Call     Nashville     Tennessee     37221  Solved
# 612   Customer Care Call        Dubois  Pennsylvania     15801  Closed
# 925             Internet  Indianapolis       Indiana     46260  Solved
# 333             Internet        Canton       Georgia     30114  Closed
#
#      Filing on Behalf of Someone
# 2159                          No
# 1392                          No
# 612                           No
# 925                          Yes
# 333                           No

# %%
df.shape
# Out:
# (2224, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date_Time                    2224 non-null   datetime64[ns]
#  1   Ticket #                     2224 non-null   object
#  2   Customer Complaint           2224 non-null   object
#  3   Date_month_year              2224 non-null   object
#  4   Received Via                 2224 non-null   object
#  5   City                         2224 non-null   object
#  6   State                        2224 non-null   object
#  7   Zip code                     2224 non-null   int64
#  8   Status                       2224 non-null   object
#  9   Filing on Behalf of Someone  2224 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 173.9+ KB

# %%
df.isna().sum()
# Out:
# Date_Time                      0
# Ticket #                       0
# Customer Complaint             0
# Date_month_year                0
# Received Via                   0
# City                           0
# State                          0
# Zip code                       0
# Status                         0
# Filing on Behalf of Someone    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### EDA

# %%
df['Month']=df['Date_Time'].dt.month

# %%
df['Month']
# Out:
# 0       4
# 1       8
# 2       4
# 3       7
# 4       5
#        ..
# 2219    2
# 2220    2
# 2221    9
# 2222    6
# 2223    6
# Name: Month, Length: 2224, dtype: int64

# %%
df['Day']=df['Date_Time'].dt.day

# %%
df['Day']
# Out:
# 0       22
# 1        4
# 2       18
# 3        5
# 4       26
#         ..
# 2219     4
# 2220     6
# 2221     6
# 2222    23
# 2223    24
# Name: Day, Length: 2224, dtype: int64

# %%
df['Customer Complaint'].value_counts()
# Out:
# Comcast                                          83
# Comcast Internet                                 18
# Comcast Data Cap                                 17
# comcast                                          13
# Comcast Billing                                  11
#                                                  ..
# Improper Billing and non resolution of issues     1
# Deceptive trade                                   1
# intermittent internet                             1
# Internet Speed on Wireless Connection             1
# Comcast, Ypsilanti MI Internet Speed              1
# Name: Customer Complaint, Length: 1841, dtype: int64

# %%
df['Customer Complaint']=df['Customer Complaint'].str.upper().str.capitalize()

# %%
df['Customer Complaint']
# Out:
# 0                           Comcast cable internet speeds
# 1            Payment disappear - service got disconnected
# 2                                       Speed and service
# 3       Comcast imposed a new usage cap of 300gb that ...
# 4              Comcast not working and no service to boot
#                               ...
# 2219                                 Service availability
# 2220           Comcast monthly billing for returned modem
# 2221                              Complaint about comcast
# 2222               Extremely unsatisfied comcast customer
# 2223                 Comcast, ypsilanti mi internet speed
# Name: Customer Complaint, Length: 2224, dtype: object

# %% [markdown]
# #### Number of Complaints in Monthly Granuality

# %%
df['Month'].value_counts().sort_index(ascending=True)
# Out:
# 1       55
# 2       59
# 3       45
# 4      375
# 5      317
# 6     1046
# 7       49
# 8       67
# 9       55
# 10      53
# 11      38
# 12      65
# Name: Month, dtype: int64

# %%
df['Day'].value_counts().sort_index(ascending=True)
# Out:
# 4     206
# 5     131
# 6     272
# 13     68
# 14     54
# 15     58
# 16     65
# 17     60
# 18     69
# 19     50
# 20     51
# 21     41
# 22     66
# 23    225
# 24    249
# 25    126
# 26     90
# 27     81
# 28     79
# 29     87
# 30     86
# 31     10
# Name: Day, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,1,2)
sns.barplot(x=df['Month'].value_counts().sort_index(ascending=True).index,y=df['Month'].value_counts().sort_index(ascending=True).values)
plt.title('Complaints in Monthly Granuality',fontsize=16,color="Red")

plt.subplot(2,1,1)
sns.barplot(x=df['Day'].value_counts().sort_index(ascending=True).index,y=df['Day'].value_counts().sort_index(ascending=True).values)
plt.title('Complaints in Daily Granuality',fontsize=16,color='Red')
plt.suptitle('Daily and Monthly wise Complaint',fontsize=18,color='Orange')
plt.show()

# %%
# Frequency of Complaint types

# %%
df["Customer Complaint"].value_counts()
# Out:
# Comcast                                                            102
# Comcast data cap                                                    30
# Comcast internet                                                    29
# Comcast data caps                                                   21
# Comcast billing                                                     18
#                                                                   ...
# Monthly data caps                                                    1
# Comcast/xfinity poor service, fraudulent billing and collection      1
# Lost emails/billing                                                  1
# Improper billing and non resolution of issues                        1
# Comcast, ypsilanti mi internet speed                                 1
# Name: Customer Complaint, Length: 1740, dtype: int64

# %%
df["Customer Complaint"].value_counts().plot(kind='barh',figsize=(20,18))
plt.title('Total Number of Complaints')
plt.show()

# %% [markdown]
# #### As we plotted all the complaints the graph is not distinguished hence ploting top 25 complaints

# %%
x=df['Customer Complaint'].value_counts().sort_values(ascending=False).head(25).index
y=df['Customer Complaint'].value_counts().sort_values(ascending=False).head(25).values

# %%
plt.figure(figsize=(18,8))
sns.barplot(x=x,y=y)
plt.title('Top 25 Complaints and Frequency',fontsize=18,color='Red')
plt.xticks(rotation=90)
plt.show()

# %%
df['Status'].value_counts()
# Out:
# Solved     973
# Closed     734
# Open       363
# Pending    154
# Name: Status, dtype: int64

# %%
New_Status=[]
for i in df['Status']:
    if i=='Pending' or i== 'Open':
        i='Open'
        New_Status.append(i)
    else:
        i='Closed'
        New_Status.append(i)

# %%
df['New Status']=New_Status

# %%
df[['Status','New Status']].value_counts()
# Out:
# Status   New Status
# Solved   Closed        973
# Closed   Closed        734
# Open     Open          363
# Pending  Open          154
# dtype: int64

# %%
# Status wise complaint

# %%
df['New Status'].value_counts()
# Out:
# Closed    1707
# Open       517
# Name: New Status, dtype: int64

# %%
plt.pie(df['New Status'].value_counts(),labels=['Closed','Open'],autopct='%.2f',pctdistance=0.5,explode=(0,0.35))
plt.title('Total Complaint Status',color='Red',fontsize=15)
plt.show()

# %%
df.columns
# Out:
# Index(['Date_Time', 'Ticket #', 'Customer Complaint', 'Date_month_year',
#        'Received Via', 'City', 'State', 'Zip code', 'Status',
#        'Filing on Behalf of Someone', 'Month', 'Day', 'New Status'],
#       dtype='object')

# %% [markdown]
# #### Complaint wise top States

# %%
df['State'].value_counts(ascending=False)
# Out:
# Georgia                 288
# Florida                 240
# California              220
# Illinois                164
# Tennessee               143
# Pennsylvania            130
# Michigan                115
# Washington               98
# Colorado                 80
# Maryland                 78
# New Jersey               75
# Texas                    71
# Massachusetts            61
# Virginia                 60
# Indiana                  59
# Oregon                   49
# Mississippi              39
# Minnesota                33
# Alabama                  26
# Utah                     22
# Arizona                  20
# South Carolina           18
# District Of Columbia     16
# New Mexico               15
# Louisiana                13
# Delaware                 12
# New Hampshire            12
# Connecticut              12
# West Virginia            11
# Kentucky                  7
# New York                  6
# Arkansas                  6
# Maine                     5
# Missouri                  4
# Ohio                      3
# Vermont                   3
# North Carolina            3
# Kansas                    2
# Nevada                    1
# Montana                   1
# Rhode Island              1
# District of Columbia      1
# Iowa                      1
# Name: State, dtype: int64

# %%
plt.figure(figsize=(14,10))
plt.barh(y=df['State'].value_counts(ascending=True).index,width=df['State'].value_counts(ascending=True).values)
plt.yticks(rotation=15)
plt.title('State wise Complaints',color='Red',fontsize=14)
plt.show()

# %% [markdown]
# #### The State "Georgia" Has maximum Complaints

# %%
df
# Out:
#                Date_Time Ticket #  \
# 0    2015-04-22 15:53:50   250635
# 1    2015-08-04 10:22:56   223441
# 2    2015-04-18 09:55:47   242732
# 3    2015-07-05 11:59:35   277946
# 4    2015-05-26 13:25:26   307175
# ...                  ...      ...
# 2219 2015-02-04 09:13:18   213550
# 2220 2015-02-06 13:24:39   318775
# 2221 2015-09-06 17:28:41   331188
# 2222 2015-06-23 23:13:30   360489
# 2223 2015-06-24 22:28:33   363614
#
#                                      Customer Complaint Date_month_year  \
# 0                         Comcast cable internet speeds       22-Apr-15
# 1          Payment disappear - service got disconnected       04-Aug-15
# 2                                     Speed and service       18-Apr-15
# 3     Comcast imposed a new usage cap of 300gb that ...       05-Jul-15
# 4            Comcast not working and no service to boot       26-May-15
# ...                                                 ...             ...
# 2219                               Service availability       04-Feb-15
# 2220         Comcast monthly billing for returned modem       06-Feb-15
# 2221                            Complaint about comcast       06-Sep-15
# 2222             Extremely unsatisfied comcast customer       23-Jun-15
# 2223               Comcast, ypsilanti mi internet speed       24-Jun-15
#
#             Received Via        City     State  Zip code  Status  \
# 0     Customer Care Call    Abingdon  Maryland     21009  Closed
# 1               Internet     Acworth   Georgia     30102  Closed
# 2               Internet     Acworth   Georgia     30101  Closed
# 3               Internet     Acworth   Georgia     30101    Open
# 4               Internet     Acworth   Georgia     30101  Solved
# ...                  ...         ...       ...       ...     ...
# 2219  Customer Care Call  Youngstown   Florida     32466  Closed
# 2220  Customer Care Call   Ypsilanti  Michigan     48197  Solved
# 2221            Internet   Ypsilanti  Michigan     48197  Solved
# 2222  Customer Care Call   Ypsilanti  Michigan     48197  Solved
# 2223  Customer Care Call   Ypsilanti  Michigan     48198    Open
#
#      Filing on Behalf of Someone  Month  Day New Status
# 0                             No      4   22     Closed
# 1                             No      8    4     Closed
# 2                            Yes      4   18     Closed
# 3                            Yes      7    5       Open
# 4                             No      5   26     Closed
# ...                          ...    ...  ...        ...
# 2219                          No      2    4     Closed
# 2220                          No      2    6     Closed
# 2221                          No      9    6     Closed
# 2222                          No      6   23     Closed
# 2223                         Yes      6   24       Open
#
# [2224 rows x 13 columns]

# %%
total_complaint=df['Customer Complaint'].value_counts().sum()

# %%
total_complaint
# Out:
# 2224

# %%
Complaints_Status=pd.crosstab(index=df['State'],columns=df['New Status'])

# %%
Complaints_Status
# Out:
# New Status            Closed  Open
# State
# Alabama                   17     9
# Arizona                   14     6
# Arkansas                   6     0
# California               159    61
# Colorado                  58    22
# Connecticut                9     3
# Delaware                   8     4
# District Of Columbia      14     2
# District of Columbia       1     0
# Florida                  201    39
# Georgia                  208    80
# Illinois                 135    29
# Indiana                   50     9
# Iowa                       1     0
# Kansas                     1     1
# Kentucky                   4     3
# Louisiana                 12     1
# Maine                      3     2
# Maryland                  63    15
# Massachusetts             50    11
# Michigan                  92    23
# Minnesota                 29     4
# Mississippi               23    16
# Missouri                   3     1
# Montana                    1     0
# Nevada                     1     0
# New Hampshire              8     4
# New Jersey                56    19
# New Mexico                11     4
# New York                   6     0
# North Carolina             3     0
# Ohio                       3     0
# Oregon                    36    13
# Pennsylvania             110    20
# Rhode Island               1     0
# South Carolina            15     3
# Tennessee                 96    47
# Texas                     49    22
# Utah                      16     6
# Vermont                    2     1
# Virginia                  49    11
# Washington                75    23
# West Virginia              8     3

# %%
Complaints_Status['Total']= Complaints_Status['Closed']+Complaints_Status['Open']

# %%
Complaints_Status
# Out:
# New Status            Closed  Open  Total
# State
# Alabama                   17     9     26
# Arizona                   14     6     20
# Arkansas                   6     0      6
# California               159    61    220
# Colorado                  58    22     80
# Connecticut                9     3     12
# Delaware                   8     4     12
# District Of Columbia      14     2     16
# District of Columbia       1     0      1
# Florida                  201    39    240
# Georgia                  208    80    288
# Illinois                 135    29    164
# Indiana                   50     9     59
# Iowa                       1     0      1
# Kansas                     1     1      2
# Kentucky                   4     3      7
# Louisiana                 12     1     13
# Maine                      3     2      5
# Maryland                  63    15     78
# Massachusetts             50    11     61
# Michigan                  92    23    115
# Minnesota                 29     4     33
# Mississippi               23    16     39
# Missouri                   3     1      4
# Montana                    1     0      1
# Nevada                     1     0      1
# New Hampshire              8     4     12
# New Jersey                56    19     75
# New Mexico                11     4     15
# New York                   6     0      6
# North Carolina             3     0      3
# Ohio                       3     0      3
# Oregon                    36    13     49
# Pennsylvania             110    20    130
# Rhode Island               1     0      1
# South Carolina            15     3     18
# Tennessee                 96    47    143
# Texas                     49    22     71
# Utah                      16     6     22
# Vermont                    2     1      3
# Virginia                  49    11     60
# Washington                75    23     98
# West Virginia              8     3     11

# %%
Complaints_Status['Open Percentage']=Complaints_Status['Open']/Complaints_Status['Total']*100
Complaints_Status['Closed Percentage']=Complaints_Status['Closed']/Complaints_Status['Total']*100

# %%
State_wise_status=Complaints_Status.sort_values(by='Open Percentage',ascending=False)

# %%
State_wise_status=State_wise_status.reset_index()

# %%
State_wise_status
# Out:
# New Status                 State  Closed  Open  Total  Open Percentage  \
# 0                         Kansas       1     1      2        50.000000
# 1                       Kentucky       4     3      7        42.857143
# 2                    Mississippi      23    16     39        41.025641
# 3                          Maine       3     2      5        40.000000
# 4                        Alabama      17     9     26        34.615385
# 5                        Vermont       2     1      3        33.333333
# 6                       Delaware       8     4     12        33.333333
# 7                  New Hampshire       8     4     12        33.333333
# 8                      Tennessee      96    47    143        32.867133
# 9                          Texas      49    22     71        30.985915
# 10                       Arizona      14     6     20        30.000000
# 11                       Georgia     208    80    288        27.777778
# 12                    California     159    61    220        27.727273
# 13                      Colorado      58    22     80        27.500000
# 14                          Utah      16     6     22        27.272727
# 15                 West Virginia       8     3     11        27.272727
# 16                    New Mexico      11     4     15        26.666667
# 17                        Oregon      36    13     49        26.530612
# 18                    New Jersey      56    19     75        25.333333
# 19                      Missouri       3     1      4        25.000000
# 20                   Connecticut       9     3     12        25.000000
# 21                    Washington      75    23     98        23.469388
# 22                      Michigan      92    23    115        20.000000
# 23                      Maryland      63    15     78        19.230769
# 24                      Virginia      49    11     60        18.333333
# 25                 Massachusetts      50    11     61        18.032787
# 26                      Illinois     135    29    164        17.682927
# 27                South Carolina      15     3     18        16.666667
# 28                       Florida     201    39    240        16.250000
# 29                  Pennsylvania     110    20    130        15.384615
# 30                       Indiana      50     9     59        15.254237
# 31          District Of Columbia      14     2     16        12.500000
# 32                     Minnesota      29     4     33        12.121212
# 33                     Louisiana      12     1     13         7.692308
# 34                  Rhode Island       1     0      1         0.000000
# 35                          Ohio       3     0      3         0.000000
# 36          District of Columbia       1     0      1         0.000000
# 37                North Carolina       3     0      3         0.000000
# 38                          Iowa       1     0      1         0.000000
# 39                      Arkansas       6     0      6         0.000000
# 40                        Nevada       1     0      1         0.000000
# 41                       Montana       1     0      1         0.000000
# 42                      New York       6     0      6         0.000000
#
# New Status  Closed Percentage
# 0                   50.000000
# 1                   57.142857
# 2                   58.974359
# 3                   60.000000
# 4                   65.384615
# 5                   66.666667
# 6                   66.666667
# 7                   66.666667
# 8                   67.132867
# 9                   69.014085
# 10                  70.000000
# 11                  72.222222
# 12                  72.272727
# 13                  72.500000
# 14                  72.727273
# 15                  72.727273
# 16                  73.333333
# 17                  73.469388
# 18                  74.666667
# 19                  75.000000
# 20                  75.000000
# 21                  76.530612
# 22                  80.000000
# 23                  80.769231
# 24                  81.666667
# 25                  81.967213
# 26                  82.317073
# 27                  83.333333
# 28                  83.750000
# 29                  84.615385
# 30                  84.745763
# 31                  87.500000
# 32                  87.878788
# 33                  92.307692
# 34                 100.000000
# 35                 100.000000
# 36                 100.000000
# 37                 100.000000
# 38                 100.000000
# 39                 100.000000
# 40                 100.000000
# 41                 100.000000
# 42                 100.000000

# %%
x=State_wise_status['State']

# %%
y=State_wise_status['Open Percentage'].values

# %%
z=State_wise_status['Closed Percentage'].values

# %%
State_wise_status['State']
# Out:
# 0                   Kansas
# 1                 Kentucky
# 2              Mississippi
# 3                    Maine
# 4                  Alabama
# 5                  Vermont
# 6                 Delaware
# 7            New Hampshire
# 8                Tennessee
# 9                    Texas
# 10                 Arizona
# 11                 Georgia
# 12              California
# 13                Colorado
# 14                    Utah
# 15           West Virginia
# 16              New Mexico
# 17                  Oregon
# 18              New Jersey
# 19                Missouri
# 20             Connecticut
# 21              Washington
# 22                Michigan
# 23                Maryland
# 24                Virginia
# 25           Massachusetts
# 26                Illinois
# 27          South Carolina
# 28                 Florida
# 29            Pennsylvania
# 30                 Indiana
# 31    District Of Columbia
# 32               Minnesota
# 33               Louisiana
# 34            Rhode Island
# 35                    Ohio
# 36    District of Columbia
# 37          North Carolina
# 38                    Iowa
# 39                Arkansas
# 40                  Nevada
# 41                 Montana
# 42                New York
# Name: State, dtype: object

# %%
plt.figure(figsize=(14,12))
plt.bar(State_wise_status['State'],State_wise_status["Open Percentage"],color='#F5B041')
plt.bar(State_wise_status['State'],State_wise_status["Closed Percentage"],bottom=State_wise_status["Open Percentage"],color='#2ECC71')
plt.legend(['Open','Closed'])
plt.title('State wise top Open and Closed tickets(%age)',fontsize=14,color="Red")
plt.xticks(rotation=70)
plt.show()
